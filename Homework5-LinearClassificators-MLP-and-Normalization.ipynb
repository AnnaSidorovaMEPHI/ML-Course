# %% [markdown]
# # MLP-classificator, нормализация признаков и persepton-dataset

# %% [markdown]
# ### Инструкция по выполнению
# - Загрузите обучающую и тестовую выборки из файлов perceptron-train.csv и perceptron-test.csv. Целевая переменная записана в первом столбце, признаки — во втором и третьем.
# - Обучите персептрон со стандартными параметрами и random_state=241.
# - Подсчитайте качество (долю правильно классифицированных объектов, accuracy) полученного классификатора на тестовой выборке.
# - Нормализуйте обучающую и тестовую выборку с помощью класса StandardScaler.
# - Обучите персептрон на новой выборке. Найдите долю правильных ответов на тестовой выборке.
# - Найдите разность между качеством на тестовой выборке после нормализации и качеством до нее. Это число и будет ответом на задание.

# %%
# !pip install scikit-learn==0.18
import numpy as np
import pandas as pd
# Out:
# Collecting scikit-learn==0.18
#   Using cached https://files.pythonhosted.org/packages/91/cf/9a1fe9d70e8fefe4f325a439a6380cd7059d1af8baa646519f4b0473b879/scikit-learn-0.18.tar.gz
# Building wheels for collected packages: scikit-learn
#   Running setup.py bdist_wheel for scikit-learn: started
#   Running setup.py bdist_wheel for scikit-learn: finished with status 'error'
#   Complete output from command C:\Users\User\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\User\\AppData\\Local\\Temp\\pip-install-3ewaj0ab\\scikit-learn\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\User\AppData\Local\Temp\pip-wheel-po23le6n --python-tag cp37:
#   Partial import of sklearn during the build process.
#   Generating cython files
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     FOUND:
#       libraries = ['mkl_rt']
#       library_dirs = ['C:/Users/User/Anaconda3\\Library\\lib']
#       define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#       include_dirs = ['C:/Users/User/Anaconda3\\Library\\include']
#
#     FOUND:
#       libraries = ['mkl_rt']
#       library_dirs = ['C:/Users/User/Anaconda3\\Library\\lib']
#       define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#       include_dirs = ['C:/Users/User/Anaconda3\\Library\\include']
#
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building library "libsvm-skl" sources
#   building extension "sklearn.__check_build._check_build" sources
#   building extension "sklearn.cluster._dbscan_inner" sources
#   building extension "sklearn.cluster._hierarchical" sources
#   building extension "sklearn.cluster._k_means_elkan" sources
#   building extension "sklearn.cluster._k_means" sources
#   building extension "sklearn.datasets._svmlight_format" sources
#   building extension "sklearn.decomposition._online_lda" sources
#   building extension "sklearn.decomposition.cdnmf_fast" sources
#   building extension "sklearn.ensemble._gradient_boosting" sources
#   building extension "sklearn.feature_extraction._hashing" sources
#   building extension "sklearn.manifold._utils" sources
#   building extension "sklearn.manifold._barnes_hut_tsne" sources
#   building extension "sklearn.metrics.pairwise_fast" sources
#   building extension "sklearn.metrics/cluster.expected_mutual_info_fast" sources
#   building extension "sklearn.neighbors.ball_tree" sources
#   building extension "sklearn.neighbors.kd_tree" sources
#   building extension "sklearn.neighbors.dist_metrics" sources
#   building extension "sklearn.neighbors.typedefs" sources
#   building extension "sklearn.tree._tree" sources
#   building extension "sklearn.tree._splitter" sources
#   building extension "sklearn.tree._criterion" sources
#   building extension "sklearn.tree._utils" sources
#   building extension "sklearn.svm.libsvm" sources
#   building extension "sklearn.svm.liblinear" sources
#   building extension "sklearn.svm.libsvm_sparse" sources
#   building extension "sklearn._isotonic" sources
#   building extension "sklearn.linear_model.cd_fast" sources
#   building extension "sklearn.linear_model.sgd_fast" sources
#   building extension "sklearn.linear_model.sag_fast" sources
#   building extension "sklearn.utils.sparsetools._traversal" sources
#   building extension "sklearn.utils.sparsetools._graph_tools" sources
#   building extension "sklearn.utils.sparsefuncs_fast" sources
#   building extension "sklearn.utils.arrayfuncs" sources
#   building extension "sklearn.utils.murmurhash" sources
#   building extension "sklearn.utils.lgamma" sources
#   building extension "sklearn.utils.graph_shortest_path" sources
#   building extension "sklearn.utils.fast_dict" sources
#   building extension "sklearn.utils.seq_dataset" sources
#   building extension "sklearn.utils.weight_vector" sources
#   building extension "sklearn.utils._random" sources
#   building extension "sklearn.utils._logistic_sigmoid" sources
#   building data_files sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\sklearn
#   copying sklearn\base.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\calibration.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\cross_validation.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\discriminant_analysis.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\dummy.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\exceptions.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\grid_search.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\isotonic.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\kernel_approximation.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\kernel_ridge.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\lda.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\learning_curve.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\multiclass.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\multioutput.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\naive_bayes.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\pipeline.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\qda.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\random_projection.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\setup.py -> build\lib.win-amd64-3.7\sklearn
#   copying sklearn\__init__.py -> build\lib.win-amd64-3.7\sklearn
#   creating build\lib.win-amd64-3.7\sklearn\__check_build
#   copying sklearn\__check_build\setup.py -> build\lib.win-amd64-3.7\sklearn\__check_build
#   copying sklearn\__check_build\__init__.py -> build\lib.win-amd64-3.7\sklearn\__check_build
#   creating build\lib.win-amd64-3.7\sklearn\_build_utils
#   copying sklearn\_build_utils\__init__.py -> build\lib.win-amd64-3.7\sklearn\_build_utils
#   creating build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\empirical_covariance_.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\graph_lasso_.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\outlier_detection.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\robust_covariance.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\shrunk_covariance_.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   copying sklearn\covariance\__init__.py -> build\lib.win-amd64-3.7\sklearn\covariance
#   creating build\lib.win-amd64-3.7\sklearn\covariance\tests
#   copying sklearn\covariance\tests\test_covariance.py -> build\lib.win-amd64-3.7\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_graph_lasso.py -> build\lib.win-amd64-3.7\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_robust_covariance.py -> build\lib.win-amd64-3.7\sklearn\covariance/tests
#   copying sklearn\covariance\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\covariance/tests
#   creating build\lib.win-amd64-3.7\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\cca_.py -> build\lib.win-amd64-3.7\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\pls_.py -> build\lib.win-amd64-3.7\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\__init__.py -> build\lib.win-amd64-3.7\sklearn\cross_decomposition
#   creating build\lib.win-amd64-3.7\sklearn\cross_decomposition\tests
#   copying sklearn\cross_decomposition\tests\test_pls.py -> build\lib.win-amd64-3.7\sklearn\cross_decomposition/tests
#   copying sklearn\cross_decomposition\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\cross_decomposition/tests
#   creating build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\base.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\from_model.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\mutual_info_.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\rfe.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\univariate_selection.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\variance_threshold.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   copying sklearn\feature_selection\__init__.py -> build\lib.win-amd64-3.7\sklearn\feature_selection
#   creating build\lib.win-amd64-3.7\sklearn\feature_selection\tests
#   copying sklearn\feature_selection\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_chi2.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_feature_select.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_from_model.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_mutual_info.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_rfe.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_variance_threshold.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\feature_selection/tests
#   creating build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\correlation_models.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gaussian_process.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpc.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpr.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\kernels.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\regression_models.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   copying sklearn\gaussian_process\__init__.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process
#   creating build\lib.win-amd64-3.7\sklearn\gaussian_process\tests
#   copying sklearn\gaussian_process\tests\test_gaussian_process.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_gpc.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_gpr.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_kernels.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\gaussian_process/tests
#   creating build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\base.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\bayesian_mixture.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\dpgmm.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\gaussian_mixture.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\gmm.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   copying sklearn\mixture\__init__.py -> build\lib.win-amd64-3.7\sklearn\mixture
#   creating build\lib.win-amd64-3.7\sklearn\mixture\tests
#   copying sklearn\mixture\tests\test_bayesian_mixture.py -> build\lib.win-amd64-3.7\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_dpgmm.py -> build\lib.win-amd64-3.7\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_gaussian_mixture.py -> build\lib.win-amd64-3.7\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_gmm.py -> build\lib.win-amd64-3.7\sklearn\mixture/tests
#   copying sklearn\mixture\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\mixture/tests
#   creating build\lib.win-amd64-3.7\sklearn\model_selection
#   copying sklearn\model_selection\_search.py -> build\lib.win-amd64-3.7\sklearn\model_selection
#   copying sklearn\model_selection\_split.py -> build\lib.win-amd64-3.7\sklearn\model_selection
#   copying sklearn\model_selection\_validation.py -> build\lib.win-amd64-3.7\sklearn\model_selection
#   copying sklearn\model_selection\__init__.py -> build\lib.win-amd64-3.7\sklearn\model_selection
#   creating build\lib.win-amd64-3.7\sklearn\model_selection\tests
#   copying sklearn\model_selection\tests\test_search.py -> build\lib.win-amd64-3.7\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_split.py -> build\lib.win-amd64-3.7\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_validation.py -> build\lib.win-amd64-3.7\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\model_selection/tests
#   creating build\lib.win-amd64-3.7\sklearn\neural_network
#   copying sklearn\neural_network\multilayer_perceptron.py -> build\lib.win-amd64-3.7\sklearn\neural_network
#   copying sklearn\neural_network\rbm.py -> build\lib.win-amd64-3.7\sklearn\neural_network
#   copying sklearn\neural_network\_base.py -> build\lib.win-amd64-3.7\sklearn\neural_network
#   copying sklearn\neural_network\_stochastic_optimizers.py -> build\lib.win-amd64-3.7\sklearn\neural_network
#   copying sklearn\neural_network\__init__.py -> build\lib.win-amd64-3.7\sklearn\neural_network
#   creating build\lib.win-amd64-3.7\sklearn\neural_network\tests
#   copying sklearn\neural_network\tests\test_mlp.py -> build\lib.win-amd64-3.7\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_rbm.py -> build\lib.win-amd64-3.7\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_stochastic_optimizers.py -> build\lib.win-amd64-3.7\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\neural_network/tests
#   creating build\lib.win-amd64-3.7\sklearn\preprocessing
#   copying sklearn\preprocessing\data.py -> build\lib.win-amd64-3.7\sklearn\preprocessing
#   copying sklearn\preprocessing\imputation.py -> build\lib.win-amd64-3.7\sklearn\preprocessing
#   copying sklearn\preprocessing\label.py -> build\lib.win-amd64-3.7\sklearn\preprocessing
#   copying sklearn\preprocessing\_function_transformer.py -> build\lib.win-amd64-3.7\sklearn\preprocessing
#   copying sklearn\preprocessing\__init__.py -> build\lib.win-amd64-3.7\sklearn\preprocessing
#   creating build\lib.win-amd64-3.7\sklearn\preprocessing\tests
#   copying sklearn\preprocessing\tests\test_data.py -> build\lib.win-amd64-3.7\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_function_transformer.py -> build\lib.win-amd64-3.7\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_imputation.py -> build\lib.win-amd64-3.7\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_label.py -> build\lib.win-amd64-3.7\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\preprocessing/tests
#   creating build\lib.win-amd64-3.7\sklearn\semi_supervised
#   copying sklearn\semi_supervised\label_propagation.py -> build\lib.win-amd64-3.7\sklearn\semi_supervised
#   copying sklearn\semi_supervised\__init__.py -> build\lib.win-amd64-3.7\sklearn\semi_supervised
#   creating build\lib.win-amd64-3.7\sklearn\semi_supervised\tests
#   copying sklearn\semi_supervised\tests\test_label_propagation.py -> build\lib.win-amd64-3.7\sklearn\semi_supervised/tests
#   copying sklearn\semi_supervised\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\semi_supervised/tests
#   creating build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\affinity_propagation_.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\bicluster.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\birch.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\dbscan_.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\hierarchical.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\k_means_.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\mean_shift_.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\setup.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\spectral.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\_feature_agglomeration.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   copying sklearn\cluster\__init__.py -> build\lib.win-amd64-3.7\sklearn\cluster
#   creating build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\common.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_affinity_propagation.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_bicluster.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_birch.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_dbscan.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_hierarchical.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_k_means.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_mean_shift.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_spectral.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   copying sklearn\cluster\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\cluster\tests
#   creating build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\base.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\california_housing.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\covtype.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\kddcup99.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\lfw.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\mlcomp.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\mldata.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\olivetti_faces.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\rcv1.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\samples_generator.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\setup.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\species_distributions.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\svmlight_format.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\twenty_newsgroups.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   copying sklearn\datasets\__init__.py -> build\lib.win-amd64-3.7\sklearn\datasets
#   creating build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_20news.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_covtype.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_kddcup99.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_lfw.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_mldata.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_rcv1.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_samples_generator.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_svmlight_format.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   copying sklearn\datasets\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\datasets\tests
#   creating build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\base.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\dict_learning.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\factor_analysis.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\fastica_.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\incremental_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\kernel_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\nmf.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\online_lda.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\setup.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\sparse_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\truncated_svd.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   copying sklearn\decomposition\__init__.py -> build\lib.win-amd64-3.7\sklearn\decomposition
#   creating build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_dict_learning.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_factor_analysis.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_fastica.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_incremental_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_kernel_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_nmf.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_online_lda.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_sparse_pca.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_truncated_svd.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\decomposition\tests
#   creating build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\bagging.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\base.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\forest.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\gradient_boosting.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\iforest.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\partial_dependence.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\setup.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\voting_classifier.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\weight_boosting.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   copying sklearn\ensemble\__init__.py -> build\lib.win-amd64-3.7\sklearn\ensemble
#   creating build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_bagging.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_forest.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting_loss_functions.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_iforest.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_partial_dependence.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_voting_classifier.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_weight_boosting.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\ensemble\tests
#   creating build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\funcsigs.py -> build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\odict.py -> build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\setup.py -> build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\six.py -> build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\test_externals_setup.py -> build\lib.win-amd64-3.7\sklearn\externals
#   copying sklearn\externals\__init__.py -> build\lib.win-amd64-3.7\sklearn\externals
#   creating build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\disk.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\format_stack.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\func_inspect.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\hashing.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\logger.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\memory.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\my_exceptions.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_compat.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_utils.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\parallel.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\pool.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\testing.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_compat.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_memory_helpers.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_multiprocessing_helpers.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_parallel_backends.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   copying sklearn\externals\joblib\__init__.py -> build\lib.win-amd64-3.7\sklearn\externals\joblib
#   creating build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\dict_vectorizer.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\hashing.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\image.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\setup.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\stop_words.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\text.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   copying sklearn\feature_extraction\__init__.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction
#   creating build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_dict_vectorizer.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_feature_hasher.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_image.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_text.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\feature_extraction\tests
#   creating build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\isomap.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\locally_linear.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\mds.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\setup.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\spectral_embedding_.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\t_sne.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   copying sklearn\manifold\__init__.py -> build\lib.win-amd64-3.7\sklearn\manifold
#   creating build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_isomap.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_locally_linear.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_mds.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_spectral_embedding.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_t_sne.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   copying sklearn\manifold\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\manifold\tests
#   creating build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\base.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\classification.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\pairwise.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\ranking.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\regression.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\scorer.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\setup.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   copying sklearn\metrics\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics
#   creating build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_classification.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_common.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_pairwise.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_ranking.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_regression.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_score_objects.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   copying sklearn\metrics\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#   creating build\lib.win-amd64-3.7\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\bicluster.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\setup.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\supervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\unsupervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#   creating build\lib.win-amd64-3.7\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_bicluster.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#   copying sklearn\metrics\cluster\tests\test_supervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#   copying sklearn\metrics\cluster\tests\test_unsupervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#   copying sklearn\metrics\cluster\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#   creating build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\approximate.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\base.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\classification.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\graph.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\kde.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\nearest_centroid.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\regression.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\setup.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\unsupervised.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   copying sklearn\neighbors\__init__.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#   creating build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_approximate.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_ball_tree.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_dist_metrics.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kde.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kd_tree.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_nearest_centroid.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_neighbors.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#   creating build\lib.win-amd64-3.7\sklearn\tree
#   copying sklearn\tree\export.py -> build\lib.win-amd64-3.7\sklearn\tree
#   copying sklearn\tree\setup.py -> build\lib.win-amd64-3.7\sklearn\tree
#   copying sklearn\tree\tree.py -> build\lib.win-amd64-3.7\sklearn\tree
#   copying sklearn\tree\__init__.py -> build\lib.win-amd64-3.7\sklearn\tree
#   creating build\lib.win-amd64-3.7\sklearn\tree\tests
#   copying sklearn\tree\tests\test_export.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#   copying sklearn\tree\tests\test_tree.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#   copying sklearn\tree\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#   creating build\lib.win-amd64-3.7\sklearn\svm
#   copying sklearn\svm\base.py -> build\lib.win-amd64-3.7\sklearn\svm
#   copying sklearn\svm\bounds.py -> build\lib.win-amd64-3.7\sklearn\svm
#   copying sklearn\svm\classes.py -> build\lib.win-amd64-3.7\sklearn\svm
#   copying sklearn\svm\setup.py -> build\lib.win-amd64-3.7\sklearn\svm
#   copying sklearn\svm\__init__.py -> build\lib.win-amd64-3.7\sklearn\svm
#   creating build\lib.win-amd64-3.7\sklearn\svm\tests
#   copying sklearn\svm\tests\test_bounds.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#   copying sklearn\svm\tests\test_sparse.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#   copying sklearn\svm\tests\test_svm.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#   copying sklearn\svm\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#   creating build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\base.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\bayes.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\huber.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\least_angle.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\logistic.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\omp.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\passive_aggressive.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\perceptron.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\randomized_l1.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\ransac.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\ridge.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\sag.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\setup.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\stochastic_gradient.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\theil_sen.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   copying sklearn\linear_model\__init__.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#   creating build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_bayes.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_huber.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_least_angle.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_logistic.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_omp.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_passive_aggressive.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_perceptron.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_randomized_l1.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ransac.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ridge.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sag.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sgd.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sparse_coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_theil_sen.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#   creating build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\arpack.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\bench.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\class_weight.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\deprecation.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\estimator_checks.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\extmath.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\fixes.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\graph.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\linear_assignment_.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\metaestimators.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\mocking.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\multiclass.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\optimize.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\random.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\setup.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\sparsefuncs.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\stats.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\testing.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\validation.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\_scipy_sparse_lsqr_backport.py -> build\lib.win-amd64-3.7\sklearn\utils
#   copying sklearn\utils\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils
#   creating build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\setup.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\_graph_validation.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#   creating build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#   copying sklearn\utils\sparsetools\tests\test_traversal.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#   copying sklearn\utils\sparsetools\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#   creating build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_bench.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_class_weight.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_estimator_checks.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_extmath.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fast_dict.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fixes.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_graph.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_linear_assignment.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_metaestimators.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_multiclass.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_murmurhash.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_optimize.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_random.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_seq_dataset.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_shortest_path.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_sparsefuncs.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_stats.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_testing.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_utils.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\test_validation.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   copying sklearn\utils\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#   creating build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_calibration.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_check_build.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_common.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_cross_validation.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_discriminant_analysis.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_dummy.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_grid_search.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_init.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_isotonic.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_kernel_approximation.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_kernel_ridge.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_learning_curve.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_metaestimators.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_multiclass.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_multioutput.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_naive_bayes.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_pipeline.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\test_random_projection.py -> build\lib.win-amd64-3.7\sklearn\tests
#   copying sklearn\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\tests
#   running build_clib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   Missing compiler_cxx fix for MSVCCompiler
#   customize MSVCCompiler using build_clib
#   building 'libsvm-skl' library
#   compiling C sources
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/
#
#   ----------------------------------------
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.19.2
#     Uninstalling scikit-learn-0.19.2:
#       Successfully uninstalled scikit-learn-0.19.2
#   Running setup.py install for scikit-learn: started
#     Running setup.py install for scikit-learn: finished with status 'error'
#     Complete output from command C:\Users\User\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\User\\AppData\\Local\\Temp\\pip-install-3ewaj0ab\\scikit-learn\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\User\AppData\Local\Temp\pip-record-nprl1_wu\install-record.txt --single-version-externally-managed --compile:
#     Partial import of sklearn during the build process.
#     Generating cython files
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       FOUND:
#         libraries = ['mkl_rt']
#         library_dirs = ['C:/Users/User/Anaconda3\\Library\\lib']
#         define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#         include_dirs = ['C:/Users/User/Anaconda3\\Library\\include']
#
#       FOUND:
#         libraries = ['mkl_rt']
#         library_dirs = ['C:/Users/User/Anaconda3\\Library\\lib']
#         define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#         include_dirs = ['C:/Users/User/Anaconda3\\Library\\include']
#
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
# ...
#     copying sklearn\metrics\tests\test_regression.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#     copying sklearn\metrics\tests\test_score_objects.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#     copying sklearn\metrics\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics\tests
#     creating build\lib.win-amd64-3.7\sklearn\metrics\cluster
#     copying sklearn\metrics\cluster\bicluster.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#     copying sklearn\metrics\cluster\setup.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#     copying sklearn\metrics\cluster\supervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#     copying sklearn\metrics\cluster\unsupervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#     copying sklearn\metrics\cluster\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster
#     creating build\lib.win-amd64-3.7\sklearn\metrics\cluster\tests
#     copying sklearn\metrics\cluster\tests\test_bicluster.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#     copying sklearn\metrics\cluster\tests\test_supervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#     copying sklearn\metrics\cluster\tests\test_unsupervised.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#     copying sklearn\metrics\cluster\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\metrics/cluster\tests
#     creating build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\approximate.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\base.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\classification.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\graph.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\kde.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\nearest_centroid.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\regression.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\setup.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\unsupervised.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     copying sklearn\neighbors\__init__.py -> build\lib.win-amd64-3.7\sklearn\neighbors
#     creating build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_approximate.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_ball_tree.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_dist_metrics.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_kde.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_kd_tree.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_nearest_centroid.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\test_neighbors.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     copying sklearn\neighbors\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\neighbors\tests
#     creating build\lib.win-amd64-3.7\sklearn\tree
#     copying sklearn\tree\export.py -> build\lib.win-amd64-3.7\sklearn\tree
#     copying sklearn\tree\setup.py -> build\lib.win-amd64-3.7\sklearn\tree
#     copying sklearn\tree\tree.py -> build\lib.win-amd64-3.7\sklearn\tree
#     copying sklearn\tree\__init__.py -> build\lib.win-amd64-3.7\sklearn\tree
#     creating build\lib.win-amd64-3.7\sklearn\tree\tests
#     copying sklearn\tree\tests\test_export.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#     copying sklearn\tree\tests\test_tree.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#     copying sklearn\tree\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\tree\tests
#     creating build\lib.win-amd64-3.7\sklearn\svm
#     copying sklearn\svm\base.py -> build\lib.win-amd64-3.7\sklearn\svm
#     copying sklearn\svm\bounds.py -> build\lib.win-amd64-3.7\sklearn\svm
#     copying sklearn\svm\classes.py -> build\lib.win-amd64-3.7\sklearn\svm
#     copying sklearn\svm\setup.py -> build\lib.win-amd64-3.7\sklearn\svm
#     copying sklearn\svm\__init__.py -> build\lib.win-amd64-3.7\sklearn\svm
#     creating build\lib.win-amd64-3.7\sklearn\svm\tests
#     copying sklearn\svm\tests\test_bounds.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#     copying sklearn\svm\tests\test_sparse.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#     copying sklearn\svm\tests\test_svm.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#     copying sklearn\svm\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\svm\tests
#     creating build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\base.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\bayes.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\huber.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\least_angle.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\logistic.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\omp.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\passive_aggressive.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\perceptron.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\randomized_l1.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\ransac.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\ridge.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\sag.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\setup.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\stochastic_gradient.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\theil_sen.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     copying sklearn\linear_model\__init__.py -> build\lib.win-amd64-3.7\sklearn\linear_model
#     creating build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_bayes.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_huber.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_least_angle.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_logistic.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_omp.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_passive_aggressive.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_perceptron.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_randomized_l1.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_ransac.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_ridge.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_sag.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_sgd.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_sparse_coordinate_descent.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\test_theil_sen.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     copying sklearn\linear_model\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\linear_model\tests
#     creating build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\arpack.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\bench.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\class_weight.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\deprecation.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\estimator_checks.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\extmath.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\fixes.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\graph.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\linear_assignment_.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\metaestimators.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\mocking.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\multiclass.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\optimize.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\random.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\setup.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\sparsefuncs.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\stats.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\testing.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\validation.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\_scipy_sparse_lsqr_backport.py -> build\lib.win-amd64-3.7\sklearn\utils
#     copying sklearn\utils\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils
#     creating build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#     copying sklearn\utils\sparsetools\setup.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#     copying sklearn\utils\sparsetools\_graph_validation.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#     copying sklearn\utils\sparsetools\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools
#     creating build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#     copying sklearn\utils\sparsetools\tests\test_traversal.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#     copying sklearn\utils\sparsetools\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\sparsetools\tests
#     creating build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_bench.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_class_weight.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_estimator_checks.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_extmath.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_fast_dict.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_fixes.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_graph.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_linear_assignment.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_metaestimators.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_multiclass.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_murmurhash.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_optimize.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_random.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_seq_dataset.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_shortest_path.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_sparsefuncs.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_stats.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_testing.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_utils.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\test_validation.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     copying sklearn\utils\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\utils\tests
#     creating build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_base.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_calibration.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_check_build.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_common.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_cross_validation.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_discriminant_analysis.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_dummy.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_grid_search.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_init.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_isotonic.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_kernel_approximation.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_kernel_ridge.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_learning_curve.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_metaestimators.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_multiclass.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_multioutput.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_naive_bayes.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_pipeline.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\test_random_projection.py -> build\lib.win-amd64-3.7\sklearn\tests
#     copying sklearn\tests\__init__.py -> build\lib.win-amd64-3.7\sklearn\tests
#     running build_clib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     Missing compiler_cxx fix for MSVCCompiler
#     customize MSVCCompiler using build_clib
#     building 'libsvm-skl' library
#     compiling C sources
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/
#
#     ----------------------------------------
#   Rolling back uninstall of scikit-learn
#   Failed building wheel for scikit-learn
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# Command "C:\Users\User\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\User\\AppData\\Local\\Temp\\pip-install-3ewaj0ab\\scikit-learn\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\User\AppData\Local\Temp\pip-record-nprl1_wu\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\User\AppData\Local\Temp\pip-install-3ewaj0ab\scikit-learn\
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
columns=['y','x1','x2']

# %%
test=pd.read_csv(r'./perceptron-test.csv',sep=',', names=columns)
train=pd.read_csv(r'./perceptron-test.csv',sep=',', names=columns)

# %%
test.head()
# Out:
#      y        x1           x2
# 0 -1.0  1.651437  1337.453826
# 1  1.0 -0.866495  1191.232457
# 2 -1.0  0.789828  -475.647768
# 3 -1.0  0.179549  1959.095353
# 4  1.0 -0.434351   568.504207

# %%
from sklearn.linear_model import Perceptron
X_train = train[['x1','x2']]
y_train = train.y
X_test = test[['x1','x2']]
y_test = test.y
clf = Perceptron(random_state=241)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.655

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(random_state=241)
clf.fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.86

# %%
0.86-0.655
# Out:
# 0.20499999999999996

# %%
#Что-то с версиями, ответ не сходится, многие пишут на форуме...
